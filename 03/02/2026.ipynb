# %% [markdown]
# <a href="https://colab.research.google.com/github/Grecia1225/2025-26-4090-Grecia-AI-B-DS/blob/main/03/02/2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Download and save the dataset in the local drive
import pandas as pd
#url of dataset(sample csv dataset)
url="https://raw.githubusercontent.com/mwaskom/seaborn-data/refs/heads/master/iris.csv"
#read dataset from url
df=pd.read_csv(url)
#display first few rows
print(df.head())
#save dataset to local drive
df.to_csv("iris.csv",index=False)
print("dataset saved successfully")
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# dataset saved successfully

# %%
#List
data = [10, 4, 8, 1, 5, 4]
# Get the number of elements
length = len(data)
print(length)
data.append(15)
print(data)
data.remove(4)
print(data)
data.sort()
print(data)
# Out:
# 6
# [10, 4, 8, 1, 5, 4, 15]
# [10, 8, 1, 5, 4, 15]
# [1, 4, 5, 8, 10, 15]

# %%
#Tuple
data = (10, 4, 8, 1, 5, 4)
print(len(data))
print(data.count(4))
print(data.index(8))
# Out:
# 6
# 2
# 2

# %%
#sets
A = {10, 4, 8, 1, 5}
B = {4, 5, 6, 7}
A.add(15)              # Adds 15 to set A
A.remove(10)           # Removes 10; raises error if 10 is missing
A.discard(99)          # Safely removes 99; no error if missing
popped = B.pop()       # Removes and returns a random element
union = A | B
inter = A & B
diff = A - B
sym_diff = A ^ B
print(f"Union (|): {union}")
print(f"Intersection (&): {inter}")
print(f"Difference (-): {diff}")
print(f"Symmetric Difference (^): {sym_diff}")
# Out:
# Union (|): {1, 4, 5, 6, 7, 8, 15}
# Intersection (&): {5}
# Difference (-): {8, 1, 4, 15}
# Symmetric Difference (^): {1, 4, 6, 7, 8, 15}

# %%
#Dictionaries
user = {
    "name": "Alice",
    "age": 25,
    "city": "New York"
}
user["email"] = "alice@example.com"
user["age"] = 26
name = user.get("name")
user.pop("city")
del user["age"]
keys = user.keys()
values = user.values()
items = user.items()
print(f"Final Dictionary: {user}")
# Out:
# Final Dictionary: {'name': 'Alice', 'email': 'alice@example.com'}
